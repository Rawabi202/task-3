# %%
import pandas as pd

# %%
import datetime

# %%
df = pd.read_csv('final_book_dataset.csv')

# %%
df.head()
# Out:
#                                                title  \
# 0  Becoming a Data Head: How to Think Speak and U...
# 1  Ace the Data Science Interview: 201 Real Inter...
# 2  Fundamentals of Data Engineering: Plan and Bui...
# 3  Essential Math for Data Science: Take Control ...
# 4  Data Science for Business: What You Need to Kn...
#
#                               author  price  pages  avg_reviews  n_reviews  \
# 0  [Alex J. Gutman,Jordan Goldmeier]  24.49  272.0          4.6        184
# 1             [Nick Singh,Kevin Huo]  26.00  301.0          4.5        599
# 2            [Joe Reis,Matt Housley]  50.76  446.0          5.0         33
# 3                     [Thomas Nield]  44.80  347.0          4.5         27
# 4       [Foster Provost,Tom Fawcett]  36.99  413.0          4.5        970
#
#    star5  star4  star3  star2  star1             dimensions       weight  \
# 0   0.74   0.18   0.05   0.02   0.01    6 x 0.62 x 9 inches  12.5 ounces
# ...

# %%
df.drop(columns='complete_link')
# Out:
#                                                  title  \
# 0    Becoming a Data Head: How to Think Speak and U...
# 1    Ace the Data Science Interview: 201 Real Inter...
# 2    Fundamentals of Data Engineering: Plan and Bui...
# 3    Essential Math for Data Science: Take Control ...
# 4    Data Science for Business: What You Need to Kn...
# ..                                                 ...
# 941  The Book of R: A First Course in Programming a...
# 942  Basic Business Statistics: A Casebook (Textboo...
# 943         Elementary Statistics: Picturing the World
# 944  Making Sense of Statistics: A Conceptual Overview
# 945                  Psychology Statistics For Dummies
#
#                                       author   price  pages  avg_reviews  \
# 0          [Alex J. Gutman,Jordan Goldmeier]   24.49  272.0          4.6
# 1                     [Nick Singh,Kevin Huo]   26.00  301.0          4.5
# 2                    [Joe Reis,Matt Housley]   50.76  446.0          5.0
# ...

# %%
df.drop(['link', 'ISBN_13'], axis=1)
# Out:
#                                                  title  \
# 0    Becoming a Data Head: How to Think Speak and U...
# 1    Ace the Data Science Interview: 201 Real Inter...
# 2    Fundamentals of Data Engineering: Plan and Bui...
# 3    Essential Math for Data Science: Take Control ...
# 4    Data Science for Business: What You Need to Kn...
# ..                                                 ...
# 941  The Book of R: A First Course in Programming a...
# 942  Basic Business Statistics: A Casebook (Textboo...
# 943         Elementary Statistics: Picturing the World
# 944  Making Sense of Statistics: A Conceptual Overview
# 945                  Psychology Statistics For Dummies
#
#                                       author   price  pages  avg_reviews  \
# 0          [Alex J. Gutman,Jordan Goldmeier]   24.49  272.0          4.6
# 1                     [Nick Singh,Kevin Huo]   26.00  301.0          4.5
# 2                    [Joe Reis,Matt Housley]   50.76  446.0          5.0
# ...

# %%
# delet row

# %%
df.drop(index=2)
# Out:
#                                                  title  \
# 0    Becoming a Data Head: How to Think Speak and U...
# 1    Ace the Data Science Interview: 201 Real Inter...
# 3    Essential Math for Data Science: Take Control ...
# 4    Data Science for Business: What You Need to Kn...
# 5    Data Science from Scratch: First Principles wi...
# ..                                                 ...
# 941  The Book of R: A First Course in Programming a...
# 942  Basic Business Statistics: A Casebook (Textboo...
# 943         Elementary Statistics: Picturing the World
# 944  Making Sense of Statistics: A Conceptual Overview
# 945                  Psychology Statistics For Dummies
#
#                                       author   price  pages  avg_reviews  \
# 0          [Alex J. Gutman,Jordan Goldmeier]   24.49  272.0          4.6
# 1                     [Nick Singh,Kevin Huo]   26.00  301.0          4.5
# 3                             [Thomas Nield]   44.80  347.0          4.5
# ...

# %%
#Delete multiple rows

# %%
df.drop([0,1,2])
# Out:
#                                                  title  \
# 3    Essential Math for Data Science: Take Control ...
# 4    Data Science for Business: What You Need to Kn...
# 5    Data Science from Scratch: First Principles wi...
# 6    Practical Statistics for Data Scientists: 50+ ...
# 7     Python for Data Science: A Hands-On Introduction
# ..                                                 ...
# 941  The Book of R: A First Course in Programming a...
# 942  Basic Business Statistics: A Casebook (Textboo...
# 943         Elementary Statistics: Picturing the World
# 944  Making Sense of Statistics: A Conceptual Overview
# 945                  Psychology Statistics For Dummies
#
#                                       author   price  pages  avg_reviews  \
# 3                             [Thomas Nield]   44.80  347.0          4.5
# 4               [Foster Provost,Tom Fawcett]   36.99  413.0          4.5
# 5                                [Joel Grus]   45.22  406.0          4.4
# ...

# %%
#Convert to floats

# %%
df= pd.DataFrame(range(4), columns=['n_reviews'])
df.n_reviews = df.n_reviews.astype(float)
df
# Out:
#    n_reviews
# 0        0.0
# 1        1.0
# 2        2.0
# 3        3.0

# %%
data_frame=pd.read_csv('final_book_dataset.csv')

# %%
print(data_frame.dtypes)
# Out:
# title             object
# author            object
# price            float64
# pages            float64
# avg_reviews      float64
# n_reviews          int64
# star5            float64
# star4            float64
# star3            float64
# star2            float64
# star1            float64
# dimensions        object
# weight            object
# language          object
# publisher         object
# ISBN_13           object
# link              object
# complete_link     object
# dtype: object

# %%
import pandas as pd
import numpy as np

# %%
def load_df(): 
  return pd.DataFrame({
    'pages': [272.0,301.0,446.0,347.0],
    'n_reviews': [184,599,33,27],
      'weight' : ['12.5 ounces', '1.28 pounds','1.57 pounds','1.23 pounds']
  })

# %%
df = load_df()
df
# Out:
#    pages  n_reviews       weight
# 0  272.0        184  12.5 ounces
# 1  301.0        599  1.28 pounds
# 2  446.0         33  1.57 pounds
# 3  347.0         27  1.23 pounds

# %%
df.dtypes
# Out:
# pages        float64
# n_reviews      int64
# weight        object
# dtype: object

# %%
df.n_reviews.dtypes
# Out:
# dtype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pages      4 non-null      float64
#  1   n_reviews  4 non-null      int64
#  2   weight     4 non-null      object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 224.0+ bytes

# %%
#Converting float to int

# %%
df['pages'] = df['pages'].astype('int')
df
# Out:
#    pages  n_reviews       weight
# 0    272        184  12.5 ounces
# 1    301        599  1.28 pounds
# 2    446         33  1.57 pounds
# 3    347         27  1.23 pounds

# %%
df = load_df()
df['pages'] = df['pages'].round(0).astype('int')
df
# Out:
#    pages  n_reviews       weight
# 0    272        184  12.5 ounces
# 1    301        599  1.28 pounds
# 2    446         33  1.57 pounds
# 3    347         27  1.23 pounds

# %%
import pandas as pd

# %%
df = pd.read_csv('final_book_dataset_kaggle 2.csv')

# %%
df.isnull()
#find missing values
# Out:
#      title  author  price  pages  avg_reviews  n_reviews  star5  star4  star3  \
# 0    False   False  False  False        False      False  False  False  False
# 1    False   False  False  False        False      False  False  False  False
# 2    False   False   True   True         True       True   True  False  False
# 3    False   False  False  False        False      False  False  False  False
# 4    False   False  False  False        False      False  False  False  False
# ..     ...     ...    ...    ...          ...        ...    ...    ...    ...
# 941  False   False  False  False        False      False  False  False  False
# 942  False   False  False  False        False      False  False  False  False
# 943  False   False  False  False        False      False  False  False  False
# 944  False   False  False  False        False      False  False  False  False
# 945  False   False  False  False        False      False  False  False  False
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 946 entries, 0 to 945
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          946 non-null    object
#  1   author         824 non-null    object
#  2   price          943 non-null    float64
#  3   pages          933 non-null    float64
#  4   avg_reviews    822 non-null    float64
#  5   n_reviews      945 non-null    float64
#  6   star5          945 non-null    float64
#  7   star4          946 non-null    float64
#  8   star3          946 non-null    float64
#  9   star2          946 non-null    float64
#  10  star1          946 non-null    float64
#  11  dimensions     914 non-null    object
#  12  weight         943 non-null    object
#  13  language       943 non-null    object
#  14  publisher      942 non-null    object
#  15  ISBN_13        945 non-null    object
#  16  link           946 non-null    object
# ...

# %%
df.describe()
# Out:
#             price        pages  avg_reviews    n_reviews       star5  \
# count  943.000000   933.000000   822.000000   945.000000  945.000000
# mean    52.104952   419.327974     4.441484   137.865608    0.625249
# std     36.610115   204.092447     0.401027   499.738599    0.279154
# min      4.730000    48.000000     1.000000     0.000000    0.000000
# 25%     31.855000   272.000000     4.300000     5.000000    0.570000
# 50%     43.970000   384.000000     4.500000    25.000000    0.700000
# 75%     56.840000   532.000000     4.700000    91.000000    0.780000
# max    279.950000  1728.000000     5.000000  7563.000000    1.000000
#
#             star4       star3       star2       star1
# count  946.000000  946.000000  946.000000  946.000000
# mean     0.140835    0.058192    0.026575    0.018732
# std      0.113105    0.061997    0.038293    0.032132
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.070000    0.000000    0.000000    0.000000
# ...

# %%
df.shape
# Out:
# (946, 18)
